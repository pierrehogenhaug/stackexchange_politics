# %%
from dask.diagnostics import ProgressBar
from dask.distributed import Client
from nltk.corpus import stopwords
from nltk.sentiment import SentimentIntensityAnalyzer
from nltk.stem import WordNetLemmatizer, PorterStemmer

import dask.dataframe as dd
import html
import psutil
import pandas as pd
import pickle as pkl
import re
import time
# Out:
# /opt/anaconda3/envs/msc/lib/python3.9/site-packages/dask/dataframe/_pyarrow_compat.py:23: UserWarning: You are using pyarrow version 14.0.0 which is known to be insecure. See https://www.cve.org/CVERecord?id=CVE-2023-47248 for further details. Please upgrade to pyarrow>=14.0.1 or install pyarrow-hotfix to patch your current version.
#   warnings.warn(

# %%
# Read the data
# Load and merge dataframes
comments = pd.concat([pd.read_pickle('./pickle_dataframes/comments1.pkl'),
                      pd.read_pickle('./pickle_dataframes/comments2.pkl')]).reset_index(drop=True)

posts = pd.concat([pd.read_pickle('./pickle_dataframes/posts1.pkl'),
                   pd.read_pickle('./pickle_dataframes/posts2.pkl'),
                   pd.read_pickle('./pickle_dataframes/posts3.pkl')]).reset_index(drop=True)

users = pd.read_pickle('./pickle_dataframes/users.pkl')

# %%
comments = comments.sample(frac=0.1, random_state=0)
posts = posts.sample(frac=0.1, random_state=0)

# %% [markdown]
# ### Filter Users on Min. Activity

# %%
# Filter posts for questions and answers
posts_qa = posts[posts['PostTypeId'].isin([1, 2])]

# Calculate user activity counts
post_count = posts_qa[posts_qa['PostTypeId'] == 1].groupby('OwnerUserId').size().rename('PostCount')
answer_count = posts_qa[posts_qa['PostTypeId'] == 2].groupby('OwnerUserId').size().rename('AnswerCount')
comment_count = comments.groupby('UserId').size().rename('CommentCount')

# %%
# Calculate number of accepted answers per user
accepted_answers = set(posts_qa[(posts_qa['PostTypeId'] == 1) & (posts_qa['OwnerUserId'] > -1)]['AcceptedAnswerId'])
accepted_answers_count = posts_qa[posts_qa['Id'].isin(accepted_answers)].groupby('OwnerUserId').size().rename('AcceptedAnswerCount')

# Merge activity counts with user data
user_activity = users.merge(post_count, left_on='Id',  right_index=True, how='left') \
                     .merge(comment_count, left_on='Id', right_index=True, how='left') \
                     .merge(accepted_answers_count, left_on='Id', right_index=True, how='left') \
                     .merge(answer_count, left_on='Id', right_index=True, how='left') \
                     .fillna({'PostCount': 0, 'CommentCount': 0, 'AcceptedAnswerCount': 0, 'AnswerCount': 0})

# %%
# Identify and process active users
active_users = user_activity.assign(TotalActivity=lambda x: x['PostCount'] + x['CommentCount'] + x['AnswerCount'])
active_users = active_users[active_users['TotalActivity'] > 15]
active_user_ids = set(active_users['Id'])

# %%
active_users
# Out:
#           Id  Reputation            CreationDate          LastAccessDate  \
# 0         -1           1 2012-12-04 20:12:06.337 2012-12-04 20:12:06.337
# 23        23       16227 2012-12-04 21:49:39.360 2015-02-14 02:38:09.917
# 96       101        9601 2012-12-05 05:03:38.487 2023-08-30 10:27:39.800
# 109      115       91134 2012-12-05 11:40:42.477 2023-09-02 00:57:59.273
# 123      130       47394 2012-12-05 21:07:06.017 2023-08-31 06:00:47.800
# ...      ...         ...                     ...                     ...
# 34261  42320        7475 2022-03-03 00:24:15.180 2023-08-22 07:22:22.197
# 34626  42710        2048 2022-03-26 18:18:39.627 2023-08-25 03:17:14.093
# 34677  42766        3416 2022-03-30 12:20:39.217 2023-09-01 18:00:55.157
# 36033  44276        4246 2022-09-05 14:11:52.263 2023-09-03 01:01:26.820
# 36739  45056        4144 2022-12-02 23:28:45.900 2023-09-02 11:42:29.477
#
#        Views  UpVotes  DownVotes  PostCount  CommentCount  \
# 0        267     5442       6725       88.0         863.0
# 23      1449      803         54        2.0          28.0
# 96      2195     2259       3113        4.0          43.0
# 109     5329     5504       2715       18.0         458.0
# 123     3958     2344        338       34.0         223.0
# ...      ...      ...        ...        ...           ...
# 34261    447      484        516        0.0          41.0
# 34626    103       62        104        0.0          17.0
# 34677     75      115         59        0.0          34.0
# 36033    153      326        201        4.0          14.0
# 36739    306      974         72        0.0          56.0
#
#        AcceptedAnswerCount  AnswerCount  TotalActivity
# 0                      5.0        157.0         1108.0
# 23                     1.0          8.0           38.0
# 96                     0.0          7.0           54.0
# 109                    3.0         67.0          543.0
# 123                    1.0         15.0          272.0
# ...                    ...          ...            ...
# 34261                  0.0          8.0           49.0
# 34626                  0.0          4.0           21.0
# 34677                  0.0          9.0           43.0
# 36033                  0.0          3.0           21.0
# 36739                  0.0          5.0           61.0
#
# [233 rows x 12 columns]

# %%
# Filter posts and comments by active users
active_posts = posts_qa[posts_qa['OwnerUserId'].isin(active_user_ids)]
parent_posts = posts_qa[posts_qa['ParentId'].isin(active_posts['Id'])]
active_posts = pd.concat([active_posts, parent_posts]).drop_duplicates()
active_posts
# Out:
#           Id  PostTypeId  ParentId  AcceptedAnswerId            CreationDate  \
# 26602  42820           2     42791                -1 2019-07-09 16:34:06.980
# 50338  79048           2     79027                -1 2023-04-04 23:04:18.057
# 28067  45617           1        -1            -19917 2019-09-17 10:49:05.153
# 35607  57753           2     57746                -1 2020-10-04 14:00:19.883
# 24743  40396           2     40379                -1 2019-04-09 09:17:20.213
# ...      ...         ...       ...               ...                     ...
# 47366  75413           2     75355                -1 2022-09-13 06:02:50.137
# 32630  52549           2     52537                -1 2020-04-07 12:01:20.917
# 23699  39158           2       904                -1 2019-03-01 22:47:31.477
# 728      855           2       406                -1 2013-01-22 17:44:49.277
# 36099  59323           2     59296                -1 2020-10-24 10:56:34.610
#
#        Score  ViewCount                                               Body  \
# 26602      0         -1  <p>In addition to the other answers, it is pos...
# 50338      9         -1  <p>As formulated this seems like an odd questi...
# 28067      2        234  <p>Noted social scientist Charles Murray has <...
# 35607      4         -1  <blockquote>&#xA;<p>In the event of a Presiden...
# 24743      4         -1  <p>Politicians often appear on T.V. as so-call...
# ...      ...        ...                                                ...
# 47366     -2         -1  <p>The premise of the question seems flawed. T...
# 32630     53         -1  <p>Republicans prevented this change because a...
# 23699     -1         -1  <p>There are many political parties in Europe ...
# 728       10         -1  <p>It may yet be too early to address the "moo...
# 36099      1         -1  <p>They don't have a winner in the same way yo...
#
#        OwnerUserId        LastActivityDate  \
# 26602        13141 2019-07-10 08:09:41.230
# 50338        21531 2023-04-05 16:36:06.123
# 28067           -1 2019-09-17 13:15:58.513
# 35607        26455 2020-10-04 14:00:19.883
# 24743         8554 2019-04-09 09:17:20.213
# ...            ...                     ...
# 47366        44350 2022-09-13 06:02:50.137
# 32630         7597 2020-04-07 14:31:13.023
# 23699        17380 2019-03-01 22:47:31.477
# 728            175 2013-01-24 15:36:02.337
# 36099        34662 2020-10-24 10:56:34.610
#
#                                                    Title  \
# 26602                                       Comment: N/A
# 50338                                       Comment: N/A
# 28067  Yang's UBI Plan: Does it Differ From Charles M...
# 35607                                       Comment: N/A
# 24743                                       Comment: N/A
# ...                                                  ...
# 47366                                       Comment: N/A
# 32630                                       Comment: N/A
# 23699                                       Comment: N/A
# 728                                         Comment: N/A
# 36099                                       Comment: N/A
#
#                                   Tags  AnswerCount  CommentCount
# 26602                     Comment: N/A           -1             6
# 50338                     Comment: N/A           -1             1
# 28067  <united-states><social-welfare>            1             1
# 35607                     Comment: N/A           -1             0
# 24743                     Comment: N/A           -1             0
# ...                                ...          ...           ...
# 47366                     Comment: N/A           -1             0
# 32630                     Comment: N/A           -1             1
# 23699                     Comment: N/A           -1             1
# 728                       Comment: N/A           -1             6
# 36099                     Comment: N/A           -1             0
#
# [3286 rows x 14 columns]

# %%
# Calculate average scores
avg_answer_score = active_posts[active_posts['PostTypeId'] == 2].groupby('OwnerUserId')['Score'].mean().rename('AvgAnswerScore')
avg_post_score = active_posts[active_posts['PostTypeId'] == 1].groupby('OwnerUserId')['Score'].mean().rename('AvgPostScore')

# %%
active_users = active_users.merge(avg_answer_score, left_on='Id', right_index=True, how='left') \
                           .merge(avg_post_score, left_on='Id', right_index=True, how='left') \
                           .fillna({'AvgAnswerScore': 0, 'AvgPostScore': 0})

# %%
active_users['AcceptedAnswerFraction'] = active_users['AcceptedAnswerCount'] / active_users['AnswerCount']

# %%
comments
# Out:
#             Id  PostId  Score  \
# 28476    56951   15807      0
# 7773     15133    3448      0
# 7744     15052    3436      0
# 180896  346006   80011      1
# 117656  226354   57061      2
# ...        ...     ...    ...
# 65821   127602   33533      0
# 156880  304320   73364      3
# 56624   110746    1828      1
# 95011   179351   45804      0
# 93968   176447   44392      0
#
#                                                      Text  \
# 28476          @DavidGrinberg Yep (not a native speaker).
# 7773    I think these can all be argued as valid, but ...
# 7744    This is a very simplistic answer. I think this...
# 180896  @JanKanis This is why I didn't use the article...
# 117656  BBC summary, in lieu of an answer: https://www...
# ...                                                   ...
# 65821   @gerrit I think they're along the right lines....
# 156880  @user366312 Stack Politics is not a political ...
# 56624   Because many people will disagree with you and...
# 95011   I've returned the book to the library already....
# 93968   @MikeScott Technically it would not need to pa...
#
#                   CreationDate  UserId
# 28476  2017-02-21 20:19:02.350    1384
# 7773   2014-07-10 00:26:10.203      -1
# 7744   2014-07-05 01:58:42.137     169
# 180896 2023-06-23 09:34:36.730   42309
# 117656 2020-09-09 16:08:22.537     300
# ...                        ...     ...
# 65821  2018-09-10 13:58:38.373   22332
# 156880 2022-05-29 17:27:54.767   41835
# 56624  2018-04-15 03:48:09.943    5894
# 95011  2019-09-23 14:28:12.830   20953
# 93968  2019-09-10 08:23:22.763    6764
#
# [18467 rows x 6 columns]

# %%
# Filter and preprocess comments
active_comments = comments[comments['PostId'].isin(active_user_ids)].drop_duplicates()
active_comments
# Out:
#            Id  PostId  Score  \
# 49227   98065   26824      0
# 21341   44242   12844      0
# 57567  112458   29927      0
# 23995   48936   14026      3
# 68849  132680   34520      1
# 37207   74533   20514      0
# 37208   74534   20514      0
# 45731   91446   25684      0
# 87253  164768   42121      0
# 5865    12182    2579      0
# 49161 2017-12-13 05:56:05.730    2130
# 20579 2016-09-29 16:09:14.320    9314
# 49236 2017-12-13 19:10:30.320   10422
# 18213 2016-06-16 20:40:14.753    7827
# 91992 2019-08-14 23:28:28.710   12531
# 7967  2014-07-21 13:31:00.647     115
# 10513 2015-01-05 00:17:24.737     115
# 7979  2014-07-21 19:49:10.003     169
# 4516  2013-10-04 14:59:56.230    2130
# 17287 2016-05-07 20:45:44.857    5407
# 87223 2019-06-13 13:17:16.943    8223
# 87243 2019-06-13 14:16:16.250   11725
# 37814 2017-07-13 07:30:28.087   13689
# 33149 2017-05-06 22:35:42.943    5215

# %% [markdown]
# ### Preprocess text

# %%
# Modify preprocess_text function
def preprocess_text(text):
    if not isinstance(text, str):
        return ""
    text = html.unescape(text)
    text = re.sub(r'<[^>]+>|[^a-zA-Z0-9]', ' ', text.lower())
    words = [WordNetLemmatizer().lemmatize(word) for word in text.split() if word not in stopwords.words('english')]
    text = ' '.join(words)

    return text

# %%
from tqdm import tqdm

tqdm.pandas()

active_comments['Text_Processed'] = ''
active_comments['Text_Processed'] = active_comments['Text'].progress_apply(lambda text: preprocess_text(text))
# Out:
# 100%|██████████| 34/34 [00:00<00:00, 146.48it/s]

# %%
# Apply preprocessing
# Comments
# ddf_comments = dd.from_pandas(active_comments, npartitions=8)
# ddf_comments['Text_Processed'] = ddf_comments['Text'].map_partitions(lambda df: df.apply(preprocess_text))
# comments_processed = ddf_comments.compute()

# %%
# # Posts
# ddf_posts = dd.from_pandas(active_posts, npartitions=8)
# ddf_posts['Body_Processed'] = ddf_posts['Body'].map_partitions(lambda df: df.apply(preprocess_text))
# ddf_posts['Title_Processed'] = ddf_posts['Title'].map_partitions(lambda df: df.apply(preprocess_text))
# posts_processed = ddf_posts.compute()

# %%
from tqdm import tqdm

tqdm.pandas()

active_posts['Body_Processed'] = ''
active_posts['Body_Processed'] = active_posts['Body'].progress_apply(lambda text: preprocess_text(text))
active_posts['Title_Processed'] = ''
active_posts['Title_Processed'] = active_posts['Title'].progress_apply(lambda text: preprocess_text(text))
# Out:
# 100%|██████████| 3286/3286 [02:08<00:00, 25.57it/s]
# 100%|██████████| 3286/3286 [00:02<00:00, 1201.06it/s]

# %%
active_posts
# Out:
#           Id  PostTypeId  ParentId  AcceptedAnswerId            CreationDate  \
# 26602  42820           2     42791                -1 2019-07-09 16:34:06.980
# 50338  79048           2     79027                -1 2023-04-04 23:04:18.057
# 28067  45617           1        -1            -19917 2019-09-17 10:49:05.153
# 35607  57753           2     57746                -1 2020-10-04 14:00:19.883
# 24743  40396           2     40379                -1 2019-04-09 09:17:20.213
# ...      ...         ...       ...               ...                     ...
# 47366  75413           2     75355                -1 2022-09-13 06:02:50.137
# 32630  52549           2     52537                -1 2020-04-07 12:01:20.917
# 23699  39158           2       904                -1 2019-03-01 22:47:31.477
# 728      855           2       406                -1 2013-01-22 17:44:49.277
# 36099  59323           2     59296                -1 2020-10-24 10:56:34.610
#
#        Score  ViewCount                                               Body  \
# 26602      0         -1  <p>In addition to the other answers, it is pos...
# 50338      9         -1  <p>As formulated this seems like an odd questi...
# 28067      2        234  <p>Noted social scientist Charles Murray has <...
# 35607      4         -1  <blockquote>&#xA;<p>In the event of a Presiden...
# 24743      4         -1  <p>Politicians often appear on T.V. as so-call...
# ...      ...        ...                                                ...
# 47366     -2         -1  <p>The premise of the question seems flawed. T...
# 32630     53         -1  <p>Republicans prevented this change because a...
# 23699     -1         -1  <p>There are many political parties in Europe ...
# 728       10         -1  <p>It may yet be too early to address the "moo...
# 36099      1         -1  <p>They don't have a winner in the same way yo...
#
#        OwnerUserId        LastActivityDate  \
# 26602        13141 2019-07-10 08:09:41.230
# 50338        21531 2023-04-05 16:36:06.123
# 28067           -1 2019-09-17 13:15:58.513
# 35607        26455 2020-10-04 14:00:19.883
# 24743         8554 2019-04-09 09:17:20.213
# ...            ...                     ...
# 47366        44350 2022-09-13 06:02:50.137
# 32630         7597 2020-04-07 14:31:13.023
# 23699        17380 2019-03-01 22:47:31.477
# 728            175 2013-01-24 15:36:02.337
# 36099        34662 2020-10-24 10:56:34.610
#
#                                                    Title  \
# 26602                                       Comment: N/A
# 50338                                       Comment: N/A
# 28067  Yang's UBI Plan: Does it Differ From Charles M...
# 35607                                       Comment: N/A
# 24743                                       Comment: N/A
# ...                                                  ...
# 47366                                       Comment: N/A
# 32630                                       Comment: N/A
# 23699                                       Comment: N/A
# 728                                         Comment: N/A
# 36099                                       Comment: N/A
#
#                                   Tags  AnswerCount  CommentCount  \
# 26602                     Comment: N/A           -1             6
# 50338                     Comment: N/A           -1             1
# 28067  <united-states><social-welfare>            1             1
# 35607                     Comment: N/A           -1             0
# 24743                     Comment: N/A           -1             0
# ...                                ...          ...           ...
# 47366                     Comment: N/A           -1             0
# 32630                     Comment: N/A           -1             1
# 23699                     Comment: N/A           -1             1
# 728                       Comment: N/A           -1             6
# 36099                     Comment: N/A           -1             0
#
#                                           Body_Processed  \
# 26602  addition answer possible looked happened uk de...
# 50338  formulated seems like odd question ask unless ...
# 28067  noted social scientist charles murray long adv...
# 35607  event presidential candidate death printing ba...
# 24743  politician often appear v called talking head ...
# ...                                                  ...
# 47366  premise question seems flawed king expressing ...
# 32630  republican prevented change core beneficial el...
# 23699  many political party europe see amnesty intern...
# 728    may yet early address moon base scenario direc...
# 36099  winner way sport yet anyway said today form po...
#
#                            Title_Processed
# 26602                            comment n
# 50338                            comment n
# 28067  yang ubi plan differ charles murray
# 35607                            comment n
# 24743                            comment n
# ...                                    ...
# 47366                            comment n
# 32630                            comment n
# 23699                            comment n
# 728                              comment n
# 36099                            comment n
#
# [3286 rows x 16 columns]

# %% [markdown]
# ### Sentiment Analysis Time

# %%
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/christianr/nltk_data...
# True

# %%
# Initialize SentimentIntensityAnalyzer once
sia = SentimentIntensityAnalyzer()

# Function to apply sentiment analysis
def analyze_sentiment(text):
    # Check if the text is missing or NaN, return 0.0 in such cases
    if pd.isna(text):
        return 0.0
    # Ensure the text is encoded as a string
    text = str(text)
    return sia.polarity_scores(text)['compound']

# %%
# # Convert pandas DataFrame to Dask DataFrame
# comments_dask = dd.from_pandas(comments_processed, npartitions=8)  # Adjust npartitions based on available memory
# posts_dask = dd.from_pandas(posts_processed, npartitions=8)  # Adjust npartitions based on available memory

# # Apply sentiment analysis to comments and posts
# comments_dask['Sentiment'] = comments_dask['Text'].map(analyze_sentiment)
# posts_dask['BodySentiment'] = posts_dask['Body'].map(analyze_sentiment)
# posts_dask['TitleSentiment'] = posts_dask['Title'].map(analyze_sentiment)

# # Compute results with progress bar
# with ProgressBar():
#     comments_result = comments_dask.compute()
#     posts_result = posts_dask.compute()
# Out:
# [########################################] | 100% Completed | 120.05 ms
# [########################################] | 100% Completed | 10.69 ss

# %%
active_comments['Sentiment'] = active_comments['Text'].progress_apply(lambda text: analyze_sentiment(text))
active_posts['BodySentiment'] = active_posts['Body'].progress_apply(lambda text: analyze_sentiment(text))
active_posts['TitleSentiment'] = active_posts['Title'].progress_apply(lambda text: analyze_sentiment(text))
# Out:
# 100%|██████████| 34/34 [00:00<00:00, 1992.38it/s]
# 100%|██████████| 3286/3286 [00:07<00:00, 438.06it/s]
# 100%|██████████| 3286/3286 [00:00<00:00, 15945.19it/s]

# %%
comments_result = active_comments.copy()
posts_result = active_posts.copy()

# %%
posts_result.head(5)
# Out:
#           Id  PostTypeId  ParentId  AcceptedAnswerId            CreationDate  \
# 26602  42820           2     42791                -1 2019-07-09 16:34:06.980
# 50338  79048           2     79027                -1 2023-04-04 23:04:18.057
# 28067  45617           1        -1            -19917 2019-09-17 10:49:05.153
# 35607  57753           2     57746                -1 2020-10-04 14:00:19.883
# 24743  40396           2     40379                -1 2019-04-09 09:17:20.213
#
#        Score  ViewCount                                               Body  \
# 26602      0         -1  <p>In addition to the other answers, it is pos...
# 50338      9         -1  <p>As formulated this seems like an odd questi...
# 28067      2        234  <p>Noted social scientist Charles Murray has <...
# 35607      4         -1  <blockquote>&#xA;<p>In the event of a Presiden...
# 24743      4         -1  <p>Politicians often appear on T.V. as so-call...
#
#        OwnerUserId        LastActivityDate  \
# 26602        13141 2019-07-10 08:09:41.230
# 50338        21531 2023-04-05 16:36:06.123
# 28067           -1 2019-09-17 13:15:58.513
# 35607        26455 2020-10-04 14:00:19.883
# 24743         8554 2019-04-09 09:17:20.213
#
#                                                    Title  \
# 26602                                       Comment: N/A
# 50338                                       Comment: N/A
# 28067  Yang's UBI Plan: Does it Differ From Charles M...
# 35607                                       Comment: N/A
# 24743                                       Comment: N/A
#
#                                   Tags  AnswerCount  CommentCount  \
# 26602                     Comment: N/A           -1             6
# 50338                     Comment: N/A           -1             1
# 28067  <united-states><social-welfare>            1             1
# 35607                     Comment: N/A           -1             0
# 24743                     Comment: N/A           -1             0
#
#                                           Body_Processed  \
# 26602  addition answer possible looked happened uk de...
# 50338  formulated seems like odd question ask unless ...
# 28067  noted social scientist charles murray long adv...
# 35607  event presidential candidate death printing ba...
# 24743  politician often appear v called talking head ...
#
#                            Title_Processed  BodySentiment  TitleSentiment
# 26602                            comment n         0.5343             0.0
# 50338                            comment n         0.8555             0.0
# 28067  yang ubi plan differ charles murray         0.6249             0.0
# 35607                            comment n         0.9907             0.0
# 24743                            comment n         0.3612             0.0

# %%
posts_result[
    posts_result.ParentId.isin(posts_result.Id.tolist())
    ].head(5)
# Out:
#           Id  PostTypeId  ParentId  AcceptedAnswerId            CreationDate  \
# 50338  79048           2     79027                -1 2023-04-04 23:04:18.057
# 24743  40396           2     40379                -1 2019-04-09 09:17:20.213
# 21639  35467           2     35460                -1 2018-11-19 15:42:50.583
# 41218  67954           2     67900                -1 2021-08-07 01:27:15.867
# 22539  37667           2     37645                -1 2019-01-04 10:14:36.640
#
#        Score  ViewCount                                               Body  \
# 50338      9         -1  <p>As formulated this seems like an odd questi...
# 24743      4         -1  <p>Politicians often appear on T.V. as so-call...
# 21639      2         -1  <p>In simple terms it means being part of a la...
# 41218      2         -1  <p>Your specific Q makes more sense focusing o...
# 22539      9         -1  <p>In the event of a no-deal crash out of the ...
#
#        OwnerUserId        LastActivityDate         Title          Tags  \
# 50338        21531 2023-04-05 16:36:06.123  Comment: N/A  Comment: N/A
# 24743         8554 2019-04-09 09:17:20.213  Comment: N/A  Comment: N/A
# 21639         6095 2018-11-19 15:42:50.583  Comment: N/A  Comment: N/A
# 41218        33430 2021-08-07 01:27:15.867  Comment: N/A  Comment: N/A
# 22539         6095 2019-01-04 10:14:36.640  Comment: N/A  Comment: N/A
#
#        AnswerCount  CommentCount  \
# 50338           -1             1
# 24743           -1             0
# 21639           -1            12
# 41218           -1             2
# 22539           -1             2
#
#                                           Body_Processed Title_Processed  \
# 50338  formulated seems like odd question ask unless ...       comment n
# 24743  politician often appear v called talking head ...       comment n
# 21639  simple term mean part larger democratic organi...       comment n
# 41218  specific q make sense focusing news calling rt...       comment n
# 22539  event deal crash eu france belgium netherlands...       comment n
#
#        BodySentiment  TitleSentiment
# 50338         0.8555             0.0
# 24743         0.3612             0.0
# 21639         0.9612             0.0
# 41218         0.4472             0.0
# 22539         0.1779             0.0

# %%
posts_result[posts_result.Id == 79027]
# Out:
#           Id  PostTypeId  ParentId  AcceptedAnswerId            CreationDate  \
# 50318  79027           1        -1             13493 2023-04-03 18:40:34.400
#
#        Score  ViewCount                                               Body  \
# 50318      2       4053  <p>Both political parties use <a href="https:/...
#
#        OwnerUserId        LastActivityDate  \
# 50318         6105 2023-04-06 14:31:19.757
#
#                                                    Title  \
# 50318  Why does the right seem to rely on "communism"...
#
#                                      Tags  AnswerCount  CommentCount  \
# 50318  <united-states><parties><rhetoric>            5             1
#
#                                           Body_Processed  \
# 50318  political party use snarl word denigrate polic...
#
#                                  Title_Processed  BodySentiment  \
# 50318  right seem rely communism snarl word left        -0.4049
#
#        TitleSentiment
# 50318             0.0

# %%
parent_list = posts_result.Id.tolist()

# %%
parent_list = posts_result.Id.tolist()
df_int = posts_result[
    posts_result.ParentId.isin(parent_list)
    ]
df_int
# Out:
#           Id  PostTypeId  ParentId  AcceptedAnswerId            CreationDate  \
# 50338  79048           2     79027                -1 2023-04-04 23:04:18.057
# 24743  40396           2     40379                -1 2019-04-09 09:17:20.213
# 21639  35467           2     35460                -1 2018-11-19 15:42:50.583
# 41218  67954           2     67900                -1 2021-08-07 01:27:15.867
# 22539  37667           2     37645                -1 2019-01-04 10:14:36.640
# ...      ...         ...       ...               ...                     ...
# 47366  75413           2     75355                -1 2022-09-13 06:02:50.137
# 32630  52549           2     52537                -1 2020-04-07 12:01:20.917
# 23699  39158           2       904                -1 2019-03-01 22:47:31.477
# 728      855           2       406                -1 2013-01-22 17:44:49.277
# 36099  59323           2     59296                -1 2020-10-24 10:56:34.610
#
#        Score  ViewCount                                               Body  \
# 50338      9         -1  <p>As formulated this seems like an odd questi...
# 24743      4         -1  <p>Politicians often appear on T.V. as so-call...
# 21639      2         -1  <p>In simple terms it means being part of a la...
# 41218      2         -1  <p>Your specific Q makes more sense focusing o...
# 22539      9         -1  <p>In the event of a no-deal crash out of the ...
# ...      ...        ...                                                ...
# 47366     -2         -1  <p>The premise of the question seems flawed. T...
# 32630     53         -1  <p>Republicans prevented this change because a...
# 23699     -1         -1  <p>There are many political parties in Europe ...
# 728       10         -1  <p>It may yet be too early to address the "moo...
# 36099      1         -1  <p>They don't have a winner in the same way yo...
#
#        OwnerUserId        LastActivityDate         Title          Tags  \
# 50338        21531 2023-04-05 16:36:06.123  Comment: N/A  Comment: N/A
# 24743         8554 2019-04-09 09:17:20.213  Comment: N/A  Comment: N/A
# 21639         6095 2018-11-19 15:42:50.583  Comment: N/A  Comment: N/A
# 41218        33430 2021-08-07 01:27:15.867  Comment: N/A  Comment: N/A
# 22539         6095 2019-01-04 10:14:36.640  Comment: N/A  Comment: N/A
# ...            ...                     ...           ...           ...
# 47366        44350 2022-09-13 06:02:50.137  Comment: N/A  Comment: N/A
# 32630         7597 2020-04-07 14:31:13.023  Comment: N/A  Comment: N/A
# 23699        17380 2019-03-01 22:47:31.477  Comment: N/A  Comment: N/A
# 728            175 2013-01-24 15:36:02.337  Comment: N/A  Comment: N/A
# 36099        34662 2020-10-24 10:56:34.610  Comment: N/A  Comment: N/A
#
#        AnswerCount  CommentCount  \
# 50338           -1             1
# 24743           -1             0
# 21639           -1            12
# 41218           -1             2
# 22539           -1             2
# ...            ...           ...
# 47366           -1             0
# 32630           -1             1
# 23699           -1             1
# 728             -1             6
# 36099           -1             0
#
#                                           Body_Processed Title_Processed  \
# 50338  formulated seems like odd question ask unless ...       comment n
# 24743  politician often appear v called talking head ...       comment n
# 21639  simple term mean part larger democratic organi...       comment n
# 41218  specific q make sense focusing news calling rt...       comment n
# 22539  event deal crash eu france belgium netherlands...       comment n
# ...                                                  ...             ...
# 47366  premise question seems flawed king expressing ...       comment n
# 32630  republican prevented change core beneficial el...       comment n
# 23699  many political party europe see amnesty intern...       comment n
# 728    may yet early address moon base scenario direc...       comment n
# 36099  winner way sport yet anyway said today form po...       comment n
#
#        BodySentiment  TitleSentiment
# 50338         0.8555             0.0
# 24743         0.3612             0.0
# 21639         0.9612             0.0
# 41218         0.4472             0.0
# 22539         0.1779             0.0
# ...              ...             ...
# 47366         0.2538             0.0
# 32630         0.9451             0.0
# 23699        -0.7016             0.0
# 728           0.8273             0.0
# 36099         0.9643             0.0
#
# [175 rows x 18 columns]

# %%
df_subpost = df_int.groupby('ParentId').agg(
    users_list=('OwnerUserId', lambda x: list(x))
).reset_index(drop=False)
df_subpost
# Out:
#      ParentId             users_list
# 0          33              [115, 73]
# 1         307                  [115]
# 2         323          [36659, 5224]
# 3         406             [193, 175]
# 4         904           [220, 17380]
# ..        ...                    ...
# 140     79055                [45750]
# 141     79918                [21949]
# 142     80260                [32479]
# 143     80384  [17668, 42582, 46306]
# 144     80542                 [2670]
#
# [145 rows x 2 columns]

# %%
df_original_poster = posts_result[posts_result.Id.isin(df_int.ParentId.tolist())].copy()
df_original_poster = df_original_poster.groupby('Id').agg(
    original_poster=('OwnerUserId', lambda x: list(x))
)
df_original_poster
# Out:
#       original_poster
# Id
# 33               [-1]
# 307             [130]
# 323             [130]
# 406             [115]
# 904             [130]
# ...               ...
# 79055         [16047]
# 79918         [22967]
# 80260         [28660]
# 80384         [21531]
# 80542         [16047]
#
# [145 rows x 1 columns]

# %%
df_graph = pd.merge(
    left=df_original_poster,
    right=df_subpost,
    left_on='Id',
    right_on='ParentId'
)

df_graph['original_poster'] = df_graph['original_poster'].apply(lambda x: x[0] if x else None)
df_graph
# Out:
#      original_poster  ParentId             users_list
# 0                 -1        33              [115, 73]
# 1                130       307                  [115]
# 2                130       323          [36659, 5224]
# 3                115       406             [193, 175]
# 4                130       904           [220, 17380]
# ..               ...       ...                    ...
# 140            16047     79055                [45750]
# 141            22967     79918                [21949]
# 142            28660     80260                [32479]
# 143            21531     80384  [17668, 42582, 46306]
# 144            16047     80542                 [2670]
#
# [145 rows x 3 columns]

# %%
import networkx as nx

G = nx.Graph()

G.add_nodes_from(df_graph['original_poster'].values)

# %%
G.nodes()
# Out:
# NodeView((-1, 130, 115, 193, 1654, 23, 5279, 2984, 5046, 2430, 270, 8808, 8647, 9016, 10373, 2130, 3169, 7434, 12027, 6738, 11278, 5894, 20263, 9638, 18373, 12531, 7476, 6116, 22967, 24065, 19165, 5534, 18862, 15671, 25684, 6890, 29927, 6105, 28994, 19301, 22118, 29035, 1953, 5571, 3164, 32479, 27084, 22860, 16047, 16957, 28067, 28660, 18367, 21531))

# %%
for idx, row in df_graph.iterrows():
    user_to = row['original_poster']
    

    users_from = row['users_list']
    if len(users_from) == 0:
        continue
    for user_from in users_from:
        G.add_edges_from([(user_to, user_from)])

# %%
G.nodes(data=True)
# Out:
# NodeDataView({-1: {}, 130: {}, 115: {}, 193: {}, 1654: {}, 23: {}, 5279: {}, 2984: {}, 5046: {}, 2430: {}, 270: {}, 8808: {}, 8647: {}, 9016: {}, 10373: {}, 2130: {}, 3169: {}, 7434: {}, 12027: {}, 6738: {}, 11278: {}, 5894: {}, 20263: {}, 9638: {}, 18373: {}, 12531: {}, 7476: {}, 6116: {}, 22967: {}, 24065: {}, 19165: {}, 5534: {}, 18862: {}, 15671: {}, 25684: {}, 6890: {}, 29927: {}, 6105: {}, 28994: {}, 19301: {}, 22118: {}, 29035: {}, 1953: {}, 5571: {}, 3164: {}, 32479: {}, 27084: {}, 22860: {}, 16047: {}, 16957: {}, 28067: {}, 28660: {}, 18367: {}, 21531: {}, 73: {}, 36659: {}, 5224: {}, 175: {}, 220: {}, 17380: {}, 15897: {}, 4330: {}, 3093: {}, 17668: {}, 6034: {}, 300: {}, 6259: {}, 7089: {}, 1827: {}, 10422: {}, 4533: {}, 6095: {}, 6659: {}, 9459: {}, 4666: {}, 7400: {}, 6927: {}, 1470: {},
# 34677                  0.0          9.0           43.0        8.555556
# 36033                  0.0          3.0           21.0        7.666667
# 36739                  0.0          5.0           61.0        3.800000
#
#        AvgPostScore  AcceptedAnswerFraction
# 0          8.886364                0.031847
# 23        10.000000                0.125000
# 96        18.000000                0.000000
# 109        8.444444                0.044776
# 123       12.500000                0.066667
# ...             ...                     ...
# 34261      0.000000                0.000000
# 34626      0.000000                0.000000
# 34677      0.000000                0.000000
# 36033      7.500000                0.000000
# 36739      0.000000                0.000000
#
# [233 rows x 15 columns]

# %%
posts_result[posts_result.OwnerUserId.isin(active_users.Id)]
# Out:
#           Id  PostTypeId  ParentId  AcceptedAnswerId            CreationDate  \
# 26602  42820           2     42791                -1 2019-07-09 16:34:06.980
# 50338  79048           2     79027                -1 2023-04-04 23:04:18.057
# 28067  45617           1        -1            -19917 2019-09-17 10:49:05.153
# 35607  57753           2     57746                -1 2020-10-04 14:00:19.883
# 24743  40396           2     40379                -1 2019-04-09 09:17:20.213
# ...      ...         ...       ...               ...                     ...
# 46510  74410           2     74399                -1 2022-07-25 16:31:54.583
# 2980    4737           1        -1              4748 2014-08-22 00:15:11.813
# 25103  40915           2     40914                -1 2019-04-22 05:06:11.817
# 31945  50622           2     13817                -1 2020-03-02 20:02:27.517
# 24692  40338           2     40334                -1 2019-04-08 00:01:05.853
#
#        Score  ViewCount                                               Body  \
# 26602      0         -1  <p>In addition to the other answers, it is pos...
# 50338      9         -1  <p>As formulated this seems like an odd questi...
# 28067      2        234  <p>Noted social scientist Charles Murray has <...
# 35607      4         -1  <blockquote>&#xA;<p>In the event of a Presiden...
# 24743      4         -1  <p>Politicians often appear on T.V. as so-call...
# ...      ...        ...                                                ...
# 46510     20         -1  <p>(Kyoto is <a href="https://treaties.un.org/...
# 2980       0        248  <p>SNAP decreased quite a bit nation wide. Wha...
# 25103      2         -1  <p>Apparently there were none; from the <a hre...
# 31945     -2         -1  <p>Ignoring the obvious reason for the militar...
# 24692     54         -1  <p>Institutions and constitutional arrangement...
#
#        OwnerUserId        LastActivityDate  \
# 26602        13141 2019-07-10 08:09:41.230
# 50338        21531 2023-04-05 16:36:06.123
# 28067           -1 2019-09-17 13:15:58.513
# 35607        26455 2020-10-04 14:00:19.883
# 24743         8554 2019-04-09 09:17:20.213
# ...            ...                     ...
# 46510        21531 2022-07-27 00:15:44.047
# 2980            -1 2014-08-24 06:00:59.557
# 25103        18373 2019-04-22 05:06:11.817
# 31945        20728 2020-03-02 20:02:27.517
# 24692        18373 2019-04-08 00:01:05.853
#
#                                                    Title  \
# 26602                                       Comment: N/A
# 50338                                       Comment: N/A
# 28067  Yang's UBI Plan: Does it Differ From Charles M...
# 35607                                       Comment: N/A
# 24743                                       Comment: N/A
# ...                                                  ...
# 46510                                       Comment: N/A
# 2980   What was the rationale behind cutting SNAP pay...
# 25103                                       Comment: N/A
# 31945                                       Comment: N/A
# 24692                                       Comment: N/A
#
#                                   Tags  AnswerCount  CommentCount  \
# 26602                     Comment: N/A           -1             6
# 50338                     Comment: N/A           -1             1
# 28067  <united-states><social-welfare>            1             1
# 35607                     Comment: N/A           -1             0
# 24743                     Comment: N/A           -1             0
# ...                                ...          ...           ...
# 46510                     Comment: N/A           -1            28
# 2980   <united-states><social-welfare>            1             5
# 25103                     Comment: N/A           -1             0
# 31945                     Comment: N/A           -1             0
# 24692                     Comment: N/A           -1             7
#
#                                           Body_Processed  \
# 26602  addition answer possible looked happened uk de...
# 50338  formulated seems like odd question ask unless ...
# 28067  noted social scientist charles murray long adv...
# 35607  event presidential candidate death printing ba...
# 24743  politician often appear v called talking head ...
# ...                                                  ...
# 46510  kyoto superseded paris protocol fwiw china rus...
# 2980   snap decreased quite bit nation wide rational ...
# 25103  apparently none official report referendum rec...
# 31945  ignoring obvious reason military existence one...
# 24692  institution constitutional arrangement importa...
#
#                                       Title_Processed  BodySentiment  \
# 26602                                       comment n         0.5343
# 50338                                       comment n         0.8555
# 28067             yang ubi plan differ charles murray         0.6249
# 35607                                       comment n         0.9907
# 24743                                       comment n         0.3612
# ...                                               ...            ...
# 46510                                       comment n        -0.4346
# 2980   rationale behind cutting snap payment increase         0.3270
# 25103                                       comment n         0.9371
# 31945                                       comment n        -0.1796
# 24692                                       comment n         0.6087
#
#        TitleSentiment
# 26602          0.0000
# 50338          0.0000
# 28067          0.0000
# 35607          0.0000
# 24743          0.0000
# ...               ...
# 46510          0.0000
# 2980           0.2869
# 25103          0.0000
# 31945          0.0000
# 24692          0.0000
#
# [3231 rows x 18 columns]

# %% [markdown]
# ### Save Results

# %%
#comments_result.to_pickle('comments_result.pkl')
#posts_result.to_pickle('posts_result.pkl')

# %%
# Calculate average sentiment for answers
avg_answer_sentiment = comments_result.groupby('PostId')['Sentiment'].mean().rename('AvgAnswerSentiment')
active_user_answers = active_users.merge(avg_answer_sentiment, left_on='Id', right_on='PostId', how='left').fillna({'AvgAnswerSentiment': 0}) \
                                  .merge(df_topics, left_on='ParentId', right_on='Id', how='left').fillna({'Topic': 'None'})

# %%
def replace_sentiment(x):
    topic = x['Topic']
    if topic == 'None':
        return 0
    sentiment = x['AvgAnswerSentiment']
    return [sentiment if int(val) > 0 else 0 for val in topic]

active_user_answers['TopicSentiment'] = active_user_answers.apply(replace_sentiment, axis=1)

# %%
def calculate_topic_sentiment(group):
    # Extract the 'Topic' column as a list of lists
    transposed_topics_sentiment = group['TopicSentiment'].transpose()
    
    # Calculate the mean for each row
    mean_values = transposed_topics_sentiment.apply(lambda x: pd.to_numeric(x, errors='coerce')).mean(axis=0)
    
    return mean_values.tolist()

# %%
# Get average answer sentiment for each user
user_avg_answer_sentiment = active_user_answers.groupby('OwnerUserId_x')['AvgAnswerSentiment'].mean().rename('AnswerSentiment')
user_answers_drop_no_sent = active_user_answers.loc[active_user_answers['TopicSentiment'] != 0]
user_avg_answer_sentiment_topic = active_user_answers[active_user_answers['TopicSentiment'] != 0].groupby('OwnerUserId_x').apply(calculate_topic_sentiment).rename('AvgTopicSentiment')

active_users = active_users.merge(user_avg_answer_sentiment, left_on='Id', right_on='OwnerUserId_x', how='left').fillna({'AnswerSentiment': 0})
active_users = active_users.merge(user_avg_answer_sentiment_topic, left_on='Id', right_on='OwnerUserId_x', how='left').fillna({'AvgTopicSentiment': 0})
